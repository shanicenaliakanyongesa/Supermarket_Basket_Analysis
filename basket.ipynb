# %%
import pandas
data=pandas.read_csv('store.csv')
data
# Out:
#         Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0                0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1                1    536365     71053                  WHITE METAL LANTERN
# 2                2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3                3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4                4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...       ...                                  ...
# 540652      541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 540653      541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 540654      541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 540655      541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 540656      541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135024
# Country             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540657 entries, 0 to 540656
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   540657 non-null  int64
#  1   InvoiceNo    540657 non-null  object
#  2   StockCode    540657 non-null  object
#  3   Description  539203 non-null  object
#  4   Quantity     540657 non-null  int64
#  5   InvoiceDate  540657 non-null  object
#  6   UnitPrice    540657 non-null  float64
#  7   CustomerID   405633 non-null  float64
#  8   Country      540657 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 37.1+ MB

# %%
data.groupby('Country').size()
# Out:
# Country
# Australia                 1257
# Austria                    387
# Bahrain                     19
# Belgium                   1971
# Brazil                      32
# Canada                     150
# Channel Islands            758
# Cyprus                     621
# Czech Republic              28
# Denmark                    375
# EIRE                      8196
# European Community          58
# Finland                    654
# France                    8246
# Germany                   9112
# Greece                     142
# Hong Kong                  286
# Iceland                    182
# Israel                     297
# Italy                      785
# Japan                      358
# Lebanon                     45
# Lithuania                   35
# Malta                      123
# Netherlands               2332
# Norway                    1066
# Poland                     336
# Portugal                  1489
# RSA                         58
# Saudi Arabia                10
# ...

# %%
data=data[data['Country']== 'France']
data
# Out:
#         Unnamed: 0 InvoiceNo StockCode                      Description  \
# 26              26    536370     22728        ALARM CLOCK BAKELIKE PINK
# 27              27    536370     22727        ALARM CLOCK BAKELIKE RED
# 28              28    536370     22726       ALARM CLOCK BAKELIKE GREEN
# 29              29    536370     21724  PANDA AND BUNNIES STICKER SHEET
# 30              30    536370     21883                 STARS GIFT TAPE
# ...            ...       ...       ...                              ...
# 540652      541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS
# 540653      541905    581587     22899     CHILDREN'S APRON DOLLY GIRL
# 540654      541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL
# 540655      541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE
# 540656      541908    581587     22138    BAKING SET 9 PIECE RETROSPOT
#
#         Quantity      InvoiceDate  UnitPrice  CustomerID Country
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# InvoiceNo       0
# StockCode       0
# Description     0
# Quantity        0
# InvoiceDate     0
# UnitPrice       0
# CustomerID     66
# Country         0
# dtype: int64

# %%
data.groupby(['InvoiceNo','Description']) ['Quantity'].sum()
# Out:
# InvoiceNo  Description
# 536370      SET 2 TEA TOWELS I LOVE LONDON      24
#            ALARM CLOCK BAKELIKE GREEN           12
#            ALARM CLOCK BAKELIKE PINK            24
#            ALARM CLOCK BAKELIKE RED             24
#            CHARLOTTE BAG DOLLY GIRL DESIGN      20
#                                                 ..
# C580263    SET OF 6 HALLOWEEN GHOST T-LIGHTS   -36
#            SKULL SHOULDER BAG                  -10
# C581316    GLASS  SONGBIRD STORAGE JAR          -1
#            RED RETROSPOT SUGAR JAM BOWL         -1
#            REGENCY SUGAR BOWL GREEN             -1
# Name: Quantity, Length: 8208, dtype: int64

# %%
pivot
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                  0.0                 0.0
# 536852                                  0.0                 0.0
# 536974                                  0.0                 0.0
# 537065                                  0.0                 0.0
# 537463                                  0.0                 0.0
# ...                                     ...                 ...
# C579192                                 0.0                 0.0
# C579532                                 0.0                 0.0
# C579562                                 0.0                 0.0
# C580263                                 0.0                 0.0
# C581316                                 0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                0.0                       0.0
# ...

# %%
#lets see each item
def each(x):
    if x<=0:
        return 0
    if x>0:
        return 1
sets=pivot.applymap(each)
sets
# Out:
# C:\Users\Shanice\AppData\Local\Temp\ipykernel_30740\2933120700.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sets=pivot.applymap(each)
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                    0                   0
# 536852                                    0                   0
# 536974                                    0                   0
# 537065                                    0                   0
# 537463                                    0                   0
# ...                                     ...                 ...
# C579192                                   0                   0
# C579532                                   0                   0
# C579562                                   0                   0
# C580263                                   0                   0
# C581316                                   0                   0
#
# ...

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
frequent_items=apriori(sets, min_support=0.07, use_colnames=True)
rules=association_rules(frequent_items,metric='lift')
rules

rules[(rules['lift']>5) & (rules['confidence']>0.7)]
# Out:
#                                           antecedents  \
# 4                          (PLASTERS IN TIN SPACEBOY)
# 6                       (SET/6 RED SPOTTY PAPER CUPS)
# 7               (SET/20 RED RETROSPOT PAPER NAPKINS )
# 8               (SET/20 RED RETROSPOT PAPER NAPKINS )
# 9                     (SET/6 RED SPOTTY PAPER PLATES)
# 10                      (SET/6 RED SPOTTY PAPER CUPS)
# 11                    (SET/6 RED SPOTTY PAPER PLATES)
# 12  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 13  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 14  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 15                      (SET/6 RED SPOTTY PAPER CUPS)
# 16              (SET/20 RED RETROSPOT PAPER NAPKINS )
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
#
#                                           consequents  antecedent support  \
# 4                  (PLASTERS IN TIN WOODLAND ANIMALS)            0.120536
# ...
